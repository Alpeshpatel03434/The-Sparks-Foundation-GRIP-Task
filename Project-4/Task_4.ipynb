# %% [markdown]
# # GRIP : The Sparks Foundation

# %% [markdown]
# ## Data Science & Business Analytics Intern

# %% [markdown]
# ## Author : Alpesh Patel

# %% [markdown]
# # Task 4 : Exploratory Data Analysis - Terrorism

# %% [markdown]
# ### Dataset - Global Terrorism - START data
# Link of dataset - https://bit.ly/2TK5Xn5

# %% [markdown]
# ## Importing the libraries

# %%
import pandas as pd
import numpy as np  
import matplotlib.pyplot as plt  
# %matplotlib inline
import seaborn as sns

# %% [markdown]
# ## Reading data
# Data can be found at https://bit.ly/2TK5Xn5

# %%
dataset = pd.read_csv("globalterrorismdb_0718dist.csv", encoding='latin1')
dataset.head()
# Out:
# d:\c_drive\python\lib\site-packages\IPython\core\interactiveshell.py:3146: DtypeWarning: Columns (4,6,31,33,61,62,63,76,79,90,92,94,96,114,115,121) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#         eventid  iyear  imonth  iday approxdate  extended resolution  country  \
# 0  197000000001   1970       7     2        NaN         0        NaN       58
# 1  197000000002   1970       0     0        NaN         0        NaN      130
# 2  197001000001   1970       1     0        NaN         0        NaN      160
# 3  197001000002   1970       1     0        NaN         0        NaN       78
# 4  197001000003   1970       1     0        NaN         0        NaN      101
#
#           country_txt  region  ... addnotes scite1 scite2  scite3  dbsource  \
# 0  Dominican Republic       2  ...      NaN    NaN    NaN     NaN      PGIS
# ...

# %%
# Shape of dataset
dataset.shape
# Out:
# (181691, 135)

# %%
# Allinformation of dataset contain
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 181691 entries, 0 to 181690
# Columns: 135 entries, eventid to related
# dtypes: float64(55), int64(22), object(58)
# memory usage: 187.1+ MB

# %%
# dtypes of each features
dataset.dtypes
# Out:
# eventid        int64
# iyear          int64
# imonth         int64
# iday           int64
# approxdate    object
#                ...
# INT_LOG        int64
# INT_IDEO       int64
# INT_MISC       int64
# INT_ANY        int64
# related       object
# Length: 135, dtype: object

# %%
# Unique value in each columns
for i in dataset.columns:
    print(i, "\t\t" ,len(dataset[i].unique()))
# Out:
# eventid 		 181691
# iyear 		 47
# imonth 		 13
# iday 		 32
# approxdate 		 2245
# extended 		 2
# resolution 		 1860
# country 		 205
# country_txt 		 205
# region 		 12
# region_txt 		 12
# provstate 		 2856
# city 		 36675
# latitude 		 48323
# longitude 		 48040
# specificity 		 6
# vicinity 		 3
# location 		 44110
# summary 		 112493
# crit1 		 2
# crit2 		 2
# crit3 		 2
# doubtterr 		 4
# alternative 		 6
# alternative_txt 		 6
# multiple 		 3
# success 		 2
# suicide 		 2
# attacktype1 		 9
# attacktype1_txt 		 9
# attacktype2 		 10
# attacktype2_txt 		 10
# attacktype3 		 9
# attacktype3_txt 		 9
# targtype1 		 22
# targtype1_txt 		 22
# targsubtype1 		 113
# targsubtype1_txt 		 113
# corp1 		 33239
# target1 		 86007
# natlty1 		 216
# natlty1_txt 		 216
# targtype2 		 23
# targtype2_txt 		 23
# targsubtype2 		 108
# targsubtype2_txt 		 108
# corp2 		 2692
# target2 		 5044
# natlty2 		 159
# natlty2_txt 		 159
# targtype3 		 21
# targtype3_txt 		 21
# targsubtype3 		 93
# ...

# %% [markdown]
# ## Find averge , min, max, etc... for Continuous Variable

# %%
# descibe numeric math
dataset.describe()
# Out:
#             eventid          iyear         imonth           iday  \
# count  1.816910e+05  181691.000000  181691.000000  181691.000000
# mean   2.002705e+11    2002.638997       6.467277      15.505644
# std    1.325957e+09      13.259430       3.388303       8.814045
# min    1.970000e+11    1970.000000       0.000000       0.000000
# 25%    1.991021e+11    1991.000000       4.000000       8.000000
# 50%    2.009022e+11    2009.000000       6.000000      15.000000
# 75%    2.014081e+11    2014.000000       9.000000      23.000000
# max    2.017123e+11    2017.000000      12.000000      31.000000
#
#             extended        country         region       latitude  \
# count  181691.000000  181691.000000  181691.000000  177135.000000
# mean        0.045346     131.968501       7.160938      23.498343
# std         0.208063     112.414535       2.933408      18.569242
# min         0.000000       4.000000       1.000000     -53.154613
# ...

# %%
# list of Features
list_columns = dataset.columns
list_columns
# Out:
# Index(['eventid', 'iyear', 'imonth', 'iday', 'approxdate', 'extended',
#        'resolution', 'country', 'country_txt', 'region',
#        ...
#        'addnotes', 'scite1', 'scite2', 'scite3', 'dbsource', 'INT_LOG',
#        'INT_IDEO', 'INT_MISC', 'INT_ANY', 'related'],
#       dtype='object', length=135)

# %%
# Each column name and there dtypes
for i in dataset.columns:
    print(i,"\t\t\t\t", dataset[i].dtypes)
# Out:
# eventid 				 int64
# iyear 				 int64
# imonth 				 int64
# iday 				 int64
# approxdate 				 object
# extended 				 int64
# resolution 				 object
# country 				 int64
# country_txt 				 object
# region 				 int64
# region_txt 				 object
# provstate 				 object
# city 				 object
# latitude 				 float64
# longitude 				 float64
# specificity 				 float64
# vicinity 				 int64
# location 				 object
# summary 				 object
# crit1 				 int64
# crit2 				 int64
# crit3 				 int64
# doubtterr 				 float64
# alternative 				 float64
# alternative_txt 				 object
# multiple 				 float64
# success 				 int64
# suicide 				 int64
# attacktype1 				 int64
# attacktype1_txt 				 object
# attacktype2 				 float64
# attacktype2_txt 				 object
# attacktype3 				 float64
# attacktype3_txt 				 object
# targtype1 				 int64
# targtype1_txt 				 object
# targsubtype1 				 float64
# targsubtype1_txt 				 object
# corp1 				 object
# target1 				 object
# natlty1 				 float64
# ...

# %% [markdown]
# ## Relationship between the data

# %%
# correlation between variables
dataset.corr()
# Out:
#             eventid     iyear    imonth      iday  extended   country  \
# eventid    1.000000  0.999996  0.002706  0.018336  0.091761 -0.135039
# iyear      0.999996  1.000000  0.000139  0.018254  0.091754 -0.135023
# imonth     0.002706  0.000139  1.000000  0.005497 -0.000468 -0.006305
# iday       0.018336  0.018254  0.005497  1.000000 -0.004700  0.003468
# extended   0.091761  0.091754 -0.000468 -0.004700  1.000000 -0.020466
# ...             ...       ...       ...       ...       ...       ...
# nreleased -0.181612 -0.181556 -0.011535  0.001765 -0.192155 -0.044331
# INT_LOG   -0.143600 -0.143601 -0.002302 -0.001540  0.071768  0.069904
# INT_IDEO  -0.133252 -0.133253 -0.002034 -0.001621  0.075147  0.067564
# INT_MISC  -0.077852 -0.077847 -0.002554 -0.002027  0.027335  0.207281
# INT_ANY   -0.175605 -0.175596 -0.006336 -0.001199  0.080767  0.153118
#
#              region  latitude  longitude  specificity  ...  ransomamt  \
# ...

# %%
# Histogram plot
dataset.hist(figsize=(50, 50))
plt.show()

# %%
plt.figure(figsize=(16, 10))
sns.barplot(x = dataset['country_txt'].value_counts()[:20].index, y = dataset['country_txt'].value_counts()[:20].values)
plt.xticks(rotation = 60, fontsize = 12)
plt.title("Top Countries Got Attacked", fontsize=16)
plt.xlabel("Countries", fontsize = 14)
plt.ylabel("Number to Attacks", fontsize = 14)
plt.show()

# %% [markdown]
# In Above Chart The most number of Attacks done at Iraq Countrie   *and*      The less number of Attacks done at Egypt Countrie.

# %% [markdown]
# So We Can say that Egpt Countrie is more Sequre then Others

# %%
plt.figure(figsize = (28, 20))
sns.countplot(x="country_txt", palette="coolwarm", data=dataset)
plt.xticks(rotation= 80)
plt.xlabel('country', fontsize = 14)
plt.ylabel('number of attacts', fontsize = 14)
plt.show()

# %%
print("Terror Attacks From ", dataset.iyear.min(), "to", dataset.iyear.max())
# Out:
# Terror Attacks From  1970 to 2017

# %%
fig, axes = plt.subplots(1, 1, figsize=(20, 10))
sns.countplot(x="iyear", palette="coolwarm", data=dataset)
plt.xticks(rotation= 80)
plt.title("Terror Attacks From 1970 to 2017", fontsize=16)
plt.show()

# %% [markdown]
# In year 2014 the most number of Terror Attacks done

# %% [markdown]
# We can see that between 1970 to 1978 the Terror Attacks are less but after 1978 it's increasing number of Attacks

# %% [markdown]
# To 2012 to 2017 years between the Most Terror Attack done so We can say Security of countries is not good enough

# %% [markdown]
# ## Death and Wound

# %%
# plot number of killed an number of wound persone
plt.figure(figsize = (10, 8))
dataset.plot(kind = 'scatter', x = 'nkill', y = 'nwound', alpha = 0.5, figsize = (10,10), fontsize=15, color = ['red'])
plt.title('Kill & Wound', fontsize=14)
plt.xlabel('Kill', fontsize=12)
plt.ylabel('Wound', fontsize=12)
plt.show()

# %% [markdown]
# In above light red dot was number of wound persone and Dark dot number of Killed persones

# %%
dataset.attacktype1_txt.hist(figsize=(20, 10))
plt.title("Attack Type", fontsize=20)
plt.xticks(rotation = 80, fontsize = 12)
plt.xlabel("attacktype1_txt", fontsize = 18)    
plt.ylabel("count", fontsize = 18)
plt.show()

# %% [markdown]
# The Frequanly most used Boombing/Explosion

# %% [markdown]
# ## Types of Attack Used By Terrorists

# %%
plt.figure(figsize=(12, 10))
sns.countplot(x=dataset["attacktype1_txt"], order=dataset["attacktype1_txt"].value_counts().index, palette="rainbow")
plt.title("Terror Attacks From 1970 to 2017", fontsize=16)
plt.xticks(rotation = 80, fontsize = 12)
plt.xlabel("attacktype1_txt", fontsize = 14)
plt.ylabel("attacktype1", fontsize = 14)
plt.show()

# %% [markdown]
# **In year 1970 to 2017 Terror Attack most frequantly type Bombing/Explosion**

# %%
plt.figure(figsize=(12, 10))
sns.countplot(x=dataset["attacktype2_txt"], order=dataset["attacktype2_txt"].value_counts().index, palette="rainbow")
plt.title("Terror Attacks From 1970 to 2017", fontsize=16)
plt.xticks(rotation = 80, fontsize = 12)
plt.xlabel("attacktype-2", fontsize = 14)
plt.ylabel("attacktype-2", fontsize = 14)
plt.show()

# %% [markdown]
# Armed Assault maximum used for attacks

# %%
plt.figure(figsize=(12, 10))
sns.countplot(x=dataset["attacktype3_txt"], order=dataset["attacktype3_txt"].value_counts().index, palette="rainbow")
plt.title("Terror Attacks From 1970 to 2017", fontsize=16)
plt.xticks(rotation = 80, fontsize = 12)
plt.xlabel("attacktype-3", fontsize = 14)
plt.ylabel("attacktype=3", fontsize = 14)
plt.show()

# %% [markdown]
# In this Attacks Facility/Infrastucture Attack larger number of Terror Attacks

# %%
plt.figure(figsize=(16, 10))
sns.barplot(x = dataset['country_txt'].value_counts()[:20].index, y = dataset['country'].value_counts()[:20].values)
plt.title("Terror Attack Country", fontsize=16)
plt.xticks(rotation = 80)
plt.xlabel("country_txt", fontsize = 14)
plt.ylabel("country", fontsize = 14)
plt.show()

# %% [markdown]
# At Iraq country number of Terror Attacks done. In Egypt less terror attacks done.

# %%
plt.figure(figsize=(14, 8))
sns.barplot(x = dataset['region_txt'].value_counts().index, y = dataset['region'].value_counts().values)
plt.title("The Attack in country Region", fontsize=16)
plt.xticks(rotation = 80, fontsize = 12)
plt.xlabel("region_txt", fontsize = 14)
plt.ylabel("region", fontsize = 14)
plt.show()

# %% [markdown]
# In Middle East and North Africa rigion most terror attecks done.

# %% [markdown]
# ## The Targets of  Attacks

# %%
plt.figure(figsize=(20, 12))
sns.barplot(x = dataset['targtype1_txt'].value_counts().index, y = dataset['targtype1'].value_counts().values)
plt.title("The Attack Targets type-1", fontsize=20)
plt.xticks(rotation = 80, fontsize = 12)
plt.xlabel("Target Type", fontsize = 18)
plt.ylabel("Target Type frequancy", fontsize = 18)
plt.show()

# %% [markdown]
# Terroriest Target was Private Citizens and Property and very few terriest target Violent political party, maritimes, Food or water supply etc

# %% [markdown]
# ## Name of Group Attacks Terrorist

# %%
plt.figure(figsize=(16, 8))
sns.barplot(x = dataset['gname'].value_counts()[:20].index, y = dataset['gname'].value_counts()[:20].values)
plt.xticks(rotation = 80, fontsize = 12)
plt.title("Tottal Group Attacks", fontsize=16)
plt.xlabel("Group Name", fontsize = 14)
plt.ylabel("Total Number of Attacks", fontsize = 14)
plt.show()

# %% [markdown]
# In Attacks done between 1997 to 2017 Terrorest group was unknown.

# %% [markdown]
# ## The Terrorist Weapen type

# %%
plt.figure(figsize=(16, 10))
sns.barplot(x = dataset['weaptype1_txt'].value_counts().index, y = dataset['weaptype1'].value_counts().values)
plt.title("The Terrorist Weapen Types", fontsize=16)
plt.xticks(rotation = 80, fontsize = 12)
plt.xlabel("Weapen Types", fontsize = 14)
plt.ylabel("Weapen Types count", fontsize = 14)
plt.show()

# %% [markdown]
# The maximum used Terror Weapen Explosives

# %%
Useful_data1 = dataset[['iyear', 'country', 'city', 'attacktype1', 'attacktype1_txt', 'targtype1', 'targtype1_txt', 'weaptype1', 'weaptype1_txt']]
Useful_data1.head()
# Out:
#    iyear  country           city  attacktype1                 attacktype1_txt  \
# 0   1970       58  Santo Domingo            1                   Assassination
# 1   1970      130    Mexico city            6     Hostage Taking (Kidnapping)
# 2   1970      160        Unknown            1                   Assassination
# 3   1970       78         Athens            3               Bombing/Explosion
# 4   1970      101        Fukouka            7  Facility/Infrastructure Attack
#
#    targtype1                targtype1_txt  weaptype1 weaptype1_txt
# 0         14  Private Citizens & Property         13       Unknown
# 1          7      Government (Diplomatic)         13       Unknown
# 2         10          Journalists & Media         13       Unknown
# 3          7      Government (Diplomatic)          6    Explosives
# 4          7      Government (Diplomatic)          8    Incendiary

# %%
Useful_data2 = dataset[['iyear', 'country', 'city', 'attacktype2', 'attacktype2_txt', 'targtype2', 'targtype2_txt', 'weaptype2', 'weaptype2_txt']]
Useful_data2.head()
# Out:
#    iyear  country           city  attacktype2 attacktype2_txt  targtype2  \
# 0   1970       58  Santo Domingo          NaN             NaN        NaN
# 1   1970      130    Mexico city          NaN             NaN        NaN
# 2   1970      160        Unknown          NaN             NaN        NaN
# 3   1970       78         Athens          NaN             NaN        NaN
# 4   1970      101        Fukouka          NaN             NaN        NaN
#
#   targtype2_txt  weaptype2 weaptype2_txt
# 0           NaN        NaN           NaN
# 1           NaN        NaN           NaN
# 2           NaN        NaN           NaN
# 3           NaN        NaN           NaN
# 4           NaN        NaN           NaN

# %%
Useful_data3 = dataset[['iyear', 'country', 'city', 'attacktype3', 'attacktype3_txt', 'targtype3', 'targtype3_txt', 'weaptype3', 'weaptype3_txt']]
Useful_data3.head()
# Out:
#    iyear  country           city  attacktype3 attacktype3_txt  targtype3  \
# 0   1970       58  Santo Domingo          NaN             NaN        NaN
# 1   1970      130    Mexico city          NaN             NaN        NaN
# 2   1970      160        Unknown          NaN             NaN        NaN
# 3   1970       78         Athens          NaN             NaN        NaN
# 4   1970      101        Fukouka          NaN             NaN        NaN
#
#   targtype3_txt  weaptype3 weaptype3_txt
# 0           NaN        NaN           NaN
# 1           NaN        NaN           NaN
# 2           NaN        NaN           NaN
# 3           NaN        NaN           NaN
# 4           NaN        NaN           NaN

# %%
data_group = dataset.groupby('city')['attacktype1', 'targtype1', 'weaptype1'].agg(sum)
data_group.head()
# Out:
# <ipython-input-29-d1b104fef259>:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   data_group = dataset.groupby('city')['attacktype1', 'targtype1', 'weaptype1'].agg(sum)
#                             attacktype1  targtype1  weaptype1
# city
# 62 miles South of Dushanbe            3          3          5
# A Coruna district                    60        102        129
# A'arbaniyeh                           3         20          6
# ANkara                                2          7          8
# Aab Kamra                             2         14          5

# %% [markdown]
# ## Conclusion

# %% [markdown]
# The Terror Attacks Between 1997 to 2017
# Between 1970 to 1978 the Terror Attacks are less but after 1978 it's increasing number of Attacks
# In 2014 the maximum number of Attacks done.
#
# Iraq country number of Terrror Attecks done.
#
# The Terror main Target was Private Citizens and Proprty.
#
# Terror used of weapen Explosive huge number of used.
